# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import random

import tensorflow as tf
from tensorflow.python.keras import Sequential
from tensorflow.keras import layers, optimizers
from tensorflow.keras.applications import DenseNet121
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.layers import *
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.initializers import glorot_uniform
from tensorflow.keras.utils import plot_model
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint, LearningRateScheduler
from IPython.display import display
from tensorflow.keras import backend as K
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from keras import optimizers
# Out:
# Using TensorFlow backend.

# %%
TRAIN_TEST_SPLIT = 0.1

# %%
readfile_dir = "drive/My Drive/Conference_ICOSES/Dataset_32p/"

# %%
list_filename = []

for species in ['Cocos', 'Eichhornia', 'Cucurbita', 'Neolamarckia']:
    if species in ['Cocos', 'Eichhornia']:
        seed_type = 'Monocot'
    elif species in ['Cucurbita', 'Neolamarckia']:
        seed_type = 'Diocot'

    for age in ['young', 'old', 'midAged']:
        for leaf_side in ['front', 'reverse']:
            filename = seed_type+'_'+species+'_'+age+'_'+leaf_side+'_32x32p.csv'
            list_filename.append(filename)
print(len(list_filename))
# Out:
# 24

# %%
train_dataset = []
test_dataset = []
train_label_seed = []
test_label_seed = []
train_label_species = []
test_label_species = []

for (file_no, filename) in enumerate(list_filename):
    print('\n',file_no+1,'.',filename,':')

    if 'Cocos' in filename:
        label_seed = 0
        label_species = 0
    elif 'Eichhornia' in filename:
        label_seed = 0
        label_species = 1
    elif 'Cucurbita' in filename:
        label_seed = 1
        label_species = 2
    elif 'Neolamarckia' in filename:
        label_seed = 1
        label_species = 3
    #
    df_dataset = pd.read_csv(readfile_dir+filename, header = None)
    df_dataset = df_dataset.drop(df_dataset.columns[[0]], axis=1)
    #print(df_dataset.shape)
    #continue
    #
    test_indices = []
    for _ in range(int(TRAIN_TEST_SPLIT*(df_dataset.shape[0]))):
        while True:
            num = random.randint(0, (int(TRAIN_TEST_SPLIT*(df_dataset.shape[0]))-1))
            if num not in test_indices:
                test_indices.append(num)
                break
    #print(len(test_indices))
    #continue
    #
    for i in range(df_dataset.shape[0]):
        reshape_data = np.reshape(df_dataset.values[i], (32,-1))
        if i in test_indices:
            test_dataset.append(reshape_data)
            test_label_seed.append(label_seed)
            test_label_species.append(label_species)
        else:
            train_dataset.append(reshape_data)
            train_label_seed.append(label_seed)
            train_label_species.append(label_species)
'''
    print('len(train_dataset)',len(train_dataset))
    print('len(train_label_seed)',len(train_label_seed))
    print('len(train_label_species)',len(train_label_species))
    print('len(test_dataset)',len(test_dataset))
    print('len(test_label_seed)',len(test_label_seed))
    print('len(test_label_species)',len(test_label_species))
#'''
# Out:
#  1 . Monocot_Cocos_young_front_32x32p.csv :
#
#  2 . Monocot_Cocos_young_reverse_32x32p.csv :
#
#  3 . Monocot_Cocos_old_front_32x32p.csv :
#
#  4 . Monocot_Cocos_old_reverse_32x32p.csv :
#
#  5 . Monocot_Cocos_midAged_front_32x32p.csv :
#
#  6 . Monocot_Cocos_midAged_reverse_32x32p.csv :
#
#  7 . Monocot_Eichhornia_young_front_32x32p.csv :
#
#  8 . Monocot_Eichhornia_young_reverse_32x32p.csv :
#
#  9 . Monocot_Eichhornia_old_front_32x32p.csv :
#
#  10 . Monocot_Eichhornia_old_reverse_32x32p.csv :
#
#  11 . Monocot_Eichhornia_midAged_front_32x32p.csv :
#
#  12 . Monocot_Eichhornia_midAged_reverse_32x32p.csv :
#
#  13 . Diocot_Cucurbita_young_front_32x32p.csv :
#
#  14 . Diocot_Cucurbita_young_reverse_32x32p.csv :
#
#  15 . Diocot_Cucurbita_old_front_32x32p.csv :
#
#  16 . Diocot_Cucurbita_old_reverse_32x32p.csv :
#
#  17 . Diocot_Cucurbita_midAged_front_32x32p.csv :
#
#  18 . Diocot_Cucurbita_midAged_reverse_32x32p.csv :
#
#  19 . Diocot_Neolamarckia_young_front_32x32p.csv :
#
#  20 . Diocot_Neolamarckia_young_reverse_32x32p.csv :
#
#  21 . Diocot_Neolamarckia_old_front_32x32p.csv :
#
#  22 . Diocot_Neolamarckia_old_reverse_32x32p.csv :
#
#  23 . Diocot_Neolamarckia_midAged_front_32x32p.csv :
#
#  24 . Diocot_Neolamarckia_midAged_reverse_32x32p.csv :
# "\n    print('len(train_dataset)',len(train_dataset))\n    print('len(train_label_seed)',len(train_label_seed))\n    print('len(train_label_species)',len(train_label_species))\n    print('len(test_dataset)',len(test_dataset))\n    print('len(test_label_seed)',len(test_label_seed))\n    print('len(test_label_species)',len(test_label_species))\n#"

# %%
#df_train_dataset = pd.DataFrame(train_dataset)
#df_test_dataset = pd.DataFrame(test_dataset)

# %%
len(train_dataset)
# Out:
# 39312

# %%
shuffle_indices = []
for _ in range(len(train_dataset)):
    while True:
        num = random.randint(0, (len(train_dataset)-1))
        if num not in shuffle_indices:
            shuffle_indices.append(num)
            break
print(len(shuffle_indices))
# Out:
# 39312

# %%
train_dataset_shuffle = []
train_label_seed_shuffle = []
train_label_species_shuffle = []

for i in shuffle_indices:
    train_dataset_shuffle.append(train_dataset[i])
    train_label_seed_shuffle.append(train_label_seed[i])
    train_label_species_shuffle.append(train_label_species[i])

# %%
num_species = 4

'''
np_train_dataset = np.array(train_dataset)/255
np_test_dataset = np.array(test_dataset)/255
np_train_label_seed = np.array(train_label_seed)
np_test_label_seed = np.array(test_label_seed)
np_train_label_species = np.array(train_label_species)/num_species
np_test_label_species = np.array(test_label_species)/num_species
#'''
np_train_dataset = np.array(train_dataset_shuffle)/255
np_test_dataset = np.array(test_dataset)/255
np_train_label_seed = np.array(train_label_seed_shuffle)
np_test_label_seed = np.array(test_label_seed)
np_train_label_species = np.array(train_label_species_shuffle)/num_species
np_test_label_species = np.array(test_label_species)/num_species

# %%
print('np_train_dataset.shape',np_train_dataset.shape)
print('np_train_label_seed.shape',np_train_label_seed.shape)
print('np_train_label_species.shape',np_train_label_species.shape)
print('np_test_dataset.shape',np_test_dataset.shape)
print('np_test_label_seed.shape',np_test_label_seed.shape)
print('np_test_label_species.shape',np_test_label_species.shape)
# Out:
# np_train_dataset.shape (39312, 32, 32)
# np_train_label_seed.shape (39312,)
# np_train_label_species.shape (39312,)
# np_test_dataset.shape (4344, 32, 32)
# np_test_label_seed.shape (4344,)
# np_test_label_species.shape (4344,)

# %%
unique_label_norm = [0.0, 0.25, 0.5, 0.75]
test_count_Cocos = 0
test_count_Eichhornia = 0
test_count_Cucurbita = 0
test_count_Neolamarckia = 0

for label in np_test_label_species:
    if label == 0.0:
        test_count_Cocos += 1
    elif label == 0.25:
        test_count_Eichhornia += 1
    elif label == 0.5:
        test_count_Cucurbita += 1
    elif label == 0.75:
        test_count_Neolamarckia += 1

print('test_count_Cocos =',test_count_Cocos)
print('test_count_Eichhornia =',test_count_Eichhornia)
print('test_count_Cucurbita =',test_count_Cucurbita)
print('test_count_Neolamarckia =',test_count_Neolamarckia)
# Out:
# test_count_Cocos = 1086
# test_count_Eichhornia = 1086
# test_count_Cucurbita = 1086
# test_count_Neolamarckia = 1086

# %%
train_count_Cocos = 0
train_count_Eichhornia = 0
train_count_Cucurbita = 0
train_count_Neolamarckia = 0

for label in np_train_label_species:
    if label == 0.0:
        train_count_Cocos += 1
    elif label == 0.25:
        train_count_Eichhornia += 1
    elif label == 0.5:
        train_count_Cucurbita += 1
    elif label == 0.75:
        train_count_Neolamarckia += 1

print('train_count_Cocos =',train_count_Cocos)
print('train_count_Eichhornia =',train_count_Eichhornia)
print('train_count_Cucurbita =',train_count_Cucurbita)
print('train_count_Neolamarckia =',train_count_Neolamarckia)
# Out:
# train_count_Cocos = 9828
# train_count_Eichhornia = 9828
# train_count_Cucurbita = 9828
# train_count_Neolamarckia = 9828

# %%
np_train_label_seed.shape
# Out:
# (39312,)

# %%
np_train_dataset2 = np.expand_dims(np_train_dataset, axis = 3)
np_train_label_seed2 = np.expand_dims(np_train_label_seed, axis = 1)

np_test_dataset2 = np.expand_dims(np_test_dataset, axis = 3)
np_test_label_seed2 = np.expand_dims(np_test_label_seed, axis = 1)

print(np_train_dataset2.shape)
print(np_train_label_seed2.shape)

print(np_test_dataset2.shape)
print(np_test_label_seed2.shape)
# Out:
# (39312, 32, 32, 1)
# (39312, 1)
# (4344, 32, 32, 1)
# (4344, 1)

# %%
np_train_dataset2.shape[1:]
# Out:
# (32, 32, 1)

# %%
def res_block(X, filter, stage):
    
  # CONVOLUTIONAL BLOCK
  X_copy = X
  f1 , f2, f3 = filter

  # Main Path
  X = Conv2D(f1, (1,1), strides = (1,1), name ='res_'+str(stage)+'_conv_a', kernel_initializer= glorot_uniform(seed = 0))(X)
  X = MaxPool2D((2,2))(X)
  X = BatchNormalization(axis =3, name = 'bn_'+str(stage)+'_conv_a')(X)
  X = Activation('relu')(X) 

  X = Conv2D(f2, kernel_size = (3,3), strides =(1,1), padding = 'same', name ='res_'+str(stage)+'_conv_b', kernel_initializer= glorot_uniform(seed = 0))(X)
  X = BatchNormalization(axis =3, name = 'bn_'+str(stage)+'_conv_b')(X)
  X = Activation('relu')(X) 

  X = Conv2D(f3, kernel_size = (1,1), strides =(1,1),name ='res_'+str(stage)+'_conv_c', kernel_initializer= glorot_uniform(seed = 0))(X)
  X = BatchNormalization(axis =3, name = 'bn_'+str(stage)+'_conv_c')(X)

  # Short path
  X_copy = Conv2D(f3, kernel_size = (1,1), strides =(1,1),name ='res_'+str(stage)+'_conv_copy', kernel_initializer= glorot_uniform(seed = 0))(X_copy)
  X_copy = MaxPool2D((2,2))(X_copy)
  X_copy = BatchNormalization(axis =3, name = 'bn_'+str(stage)+'_conv_copy')(X_copy)

  # Add data from main and short paths
  X = Add()([X,X_copy])
  X = Activation('relu')(X)

    
    
  # IDENTITY BLOCK 1
  X_copy = X
    
  # Main Path
  X = Conv2D(f1, (1,1),strides = (1,1), name ='res_'+str(stage)+'_identity_1_a', kernel_initializer= glorot_uniform(seed = 0))(X)
  X = BatchNormalization(axis =3, name = 'bn_'+str(stage)+'_identity_1_a')(X)
  X = Activation('relu')(X) 

  X = Conv2D(f2, kernel_size = (3,3), strides =(1,1), padding = 'same', name ='res_'+str(stage)+'_identity_1_b', kernel_initializer= glorot_uniform(seed = 0))(X)
  X = BatchNormalization(axis =3, name = 'bn_'+str(stage)+'_identity_1_b')(X)
  X = Activation('relu')(X) 

  X = Conv2D(f3, kernel_size = (1,1), strides =(1,1),name ='res_'+str(stage)+'_identity_1_c', kernel_initializer= glorot_uniform(seed = 0))(X)
  X = BatchNormalization(axis =3, name = 'bn_'+str(stage)+'_identity_1_c')(X)

  # Add both paths together (Note that we feed the original input as is hence the name "identity")
  X = Add()([X,X_copy])
  X = Activation('relu')(X)

    
    
  # IDENTITY BLOCK 2
  X_copy = X

  # Main Path
  X = Conv2D(f1, (1,1),strides = (1,1), name ='res_'+str(stage)+'_identity_2_a', kernel_initializer= glorot_uniform(seed = 0))(X)
  X = BatchNormalization(axis =3, name = 'bn_'+str(stage)+'_identity_2_a')(X)
  X = Activation('relu')(X) 

  X = Conv2D(f2, kernel_size = (3,3), strides =(1,1), padding = 'same', name ='res_'+str(stage)+'_identity_2_b', kernel_initializer= glorot_uniform(seed = 0))(X)
  X = BatchNormalization(axis =3, name = 'bn_'+str(stage)+'_identity_2_b')(X)
  X = Activation('relu')(X) 

  X = Conv2D(f3, kernel_size = (1,1), strides =(1,1),name ='res_'+str(stage)+'_identity_2_c', kernel_initializer= glorot_uniform(seed = 0))(X)
  X = BatchNormalization(axis =3, name = 'bn_'+str(stage)+'_identity_2_c')(X)

  # Add both paths together (Note that we feed the original input as is hence the name "identity")
  X = Add()([X,X_copy])
  X = Activation('relu')(X)

  return X

# %%
input_shape = np_train_dataset2.shape[1:] #(32,32,1) #np_train_dataset.shape #np.expand_dims(np_train_dataset, axis=1) #

# Input tensor shape
X_input = Input(input_shape)

# Zero-padding
X = ZeroPadding2D((4,4))(X_input)
#X = Input(input_shape)

# Stage #1
X = Conv2D(64, (5,5), strides= (1,1), name = 'conv1', kernel_initializer= glorot_uniform(seed = 0))(X)
#X = Conv2D(64, np_train_dataset.shape[1:3], strides= (2,2), name = 'conv1', kernel_initializer= glorot_uniform(seed = 0), data_format='channels_first')(X)
#X = Conv2D(64, np_train_dataset.shape[1:3], strides= (2,2), name = 'conv1', kernel_initializer= glorot_uniform(seed = 0), data_format='channels_first')(X)
X = BatchNormalization(axis =3, name = 'bn_conv1')(X)
X = Activation('relu')(X)
#print('ok1')
X = MaxPooling2D((3,3), strides= (1,1))(X)
#print('ok2')
num_stage = 1
# Stage #2
#X = res_block(X, filter= [64,64,256], stage = num_stage+1)

# Stage #3
X = res_block(X, filter= [128,512,128], stage = 2)

X = res_block(X, filter= [256,1024,256], stage = 3)

X = res_block(X, filter= [512,1024,256], stage = 4)

X = res_block(X, filter= [256,1024,256], stage = 5)

#X = res_block(X, filter= [128,512,128], stage = num_stage+1)

#X = res_block(X, filter= [64,64,256], stage = num_stage+1)

# Average Pooling
X = AveragePooling2D((2,2), name = 'Averagea_Pooling')(X)

# Final layer
X = Flatten()(X)
X = Dense(4096, activation = 'relu')(X)
X = Dropout(0.2)(X)
X = Dense(2048, activation = 'relu')(X)
X = Dropout(0.1)(X)
X = Dense(1024, activation = 'relu')(X)
X = Dense(512, activation = 'relu')(X)
X = Dense(1, activation = 'sigmoid')(X)


model = Model( inputs= X_input, outputs = X)
model.summary()
# Out:
# Model: "model_6"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_10 (InputLayer)           [(None, 32, 32, 1)]  0
# __________________________________________________________________________________________________
# zero_padding2d_9 (ZeroPadding2D (None, 40, 40, 1)    0           input_10[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 36, 36, 64)   1664        zero_padding2d_9[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (None, 36, 36, 64)   256         conv1[0][0]
# __________________________________________________________________________________________________
# activation_360 (Activation)     (None, 36, 36, 64)   0           bn_conv1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_87 (MaxPooling2D) (None, 34, 34, 64)   0           activation_360[0][0]
# __________________________________________________________________________________________________
# res_2_conv_a (Conv2D)           (None, 34, 34, 128)  8320        max_pooling2d_87[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_88 (MaxPooling2D) (None, 17, 17, 128)  0           res_2_conv_a[0][0]
# __________________________________________________________________________________________________
# bn_2_conv_a (BatchNormalization (None, 17, 17, 128)  512         max_pooling2d_88[0][0]
# __________________________________________________________________________________________________
# activation_361 (Activation)     (None, 17, 17, 128)  0           bn_2_conv_a[0][0]
# __________________________________________________________________________________________________
# res_2_conv_b (Conv2D)           (None, 17, 17, 512)  590336      activation_361[0][0]
# __________________________________________________________________________________________________
# bn_2_conv_b (BatchNormalization (None, 17, 17, 512)  2048        res_2_conv_b[0][0]
# __________________________________________________________________________________________________
# activation_362 (Activation)     (None, 17, 17, 512)  0           bn_2_conv_b[0][0]
# __________________________________________________________________________________________________
# res_2_conv_copy (Conv2D)        (None, 34, 34, 128)  8320        max_pooling2d_87[0][0]
# __________________________________________________________________________________________________
# res_2_conv_c (Conv2D)           (None, 17, 17, 128)  65664       activation_362[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_89 (MaxPooling2D) (None, 17, 17, 128)  0           res_2_conv_copy[0][0]
# __________________________________________________________________________________________________
# bn_2_conv_c (BatchNormalization (None, 17, 17, 128)  512         res_2_conv_c[0][0]
# __________________________________________________________________________________________________
# bn_2_conv_copy (BatchNormalizat (None, 17, 17, 128)  512         max_pooling2d_89[0][0]
# __________________________________________________________________________________________________
# add_117 (Add)                   (None, 17, 17, 128)  0           bn_2_conv_c[0][0]
#                                                                  bn_2_conv_copy[0][0]
# __________________________________________________________________________________________________
# activation_363 (Activation)     (None, 17, 17, 128)  0           add_117[0][0]
# __________________________________________________________________________________________________
# res_2_identity_1_a (Conv2D)     (None, 17, 17, 128)  16512       activation_363[0][0]
# __________________________________________________________________________________________________
# bn_2_identity_1_a (BatchNormali (None, 17, 17, 128)  512         res_2_identity_1_a[0][0]
# __________________________________________________________________________________________________
# activation_364 (Activation)     (None, 17, 17, 128)  0           bn_2_identity_1_a[0][0]
# __________________________________________________________________________________________________
# res_2_identity_1_b (Conv2D)     (None, 17, 17, 512)  590336      activation_364[0][0]
# __________________________________________________________________________________________________
# bn_2_identity_1_b (BatchNormali (None, 17, 17, 512)  2048        res_2_identity_1_b[0][0]
# __________________________________________________________________________________________________
# activation_365 (Activation)     (None, 17, 17, 512)  0           bn_2_identity_1_b[0][0]
# __________________________________________________________________________________________________
# res_2_identity_1_c (Conv2D)     (None, 17, 17, 128)  65664       activation_365[0][0]
# __________________________________________________________________________________________________
# bn_2_identity_1_c (BatchNormali (None, 17, 17, 128)  512         res_2_identity_1_c[0][0]
# __________________________________________________________________________________________________
# add_118 (Add)                   (None, 17, 17, 128)  0           bn_2_identity_1_c[0][0]
#                                                                  activation_363[0][0]
# __________________________________________________________________________________________________
# activation_366 (Activation)     (None, 17, 17, 128)  0           add_118[0][0]
# __________________________________________________________________________________________________
# res_2_identity_2_a (Conv2D)     (None, 17, 17, 128)  16512       activation_366[0][0]
# __________________________________________________________________________________________________
# bn_2_identity_2_a (BatchNormali (None, 17, 17, 128)  512         res_2_identity_2_a[0][0]
# __________________________________________________________________________________________________
# activation_367 (Activation)     (None, 17, 17, 128)  0           bn_2_identity_2_a[0][0]
# __________________________________________________________________________________________________
# res_2_identity_2_b (Conv2D)     (None, 17, 17, 512)  590336      activation_367[0][0]
# __________________________________________________________________________________________________
# bn_2_identity_2_b (BatchNormali (None, 17, 17, 512)  2048        res_2_identity_2_b[0][0]
# __________________________________________________________________________________________________
# activation_368 (Activation)     (None, 17, 17, 512)  0           bn_2_identity_2_b[0][0]
# __________________________________________________________________________________________________
# res_2_identity_2_c (Conv2D)     (None, 17, 17, 128)  65664       activation_368[0][0]
# __________________________________________________________________________________________________
# bn_2_identity_2_c (BatchNormali (None, 17, 17, 128)  512         res_2_identity_2_c[0][0]
# __________________________________________________________________________________________________
# add_119 (Add)                   (None, 17, 17, 128)  0           bn_2_identity_2_c[0][0]
#                                                                  activation_366[0][0]
# __________________________________________________________________________________________________
# activation_369 (Activation)     (None, 17, 17, 128)  0           add_119[0][0]
# __________________________________________________________________________________________________
# res_3_conv_a (Conv2D)           (None, 17, 17, 256)  33024       activation_369[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_90 (MaxPooling2D) (None, 8, 8, 256)    0           res_3_conv_a[0][0]
# __________________________________________________________________________________________________
# bn_3_conv_a (BatchNormalization (None, 8, 8, 256)    1024        max_pooling2d_90[0][0]
# __________________________________________________________________________________________________
# activation_370 (Activation)     (None, 8, 8, 256)    0           bn_3_conv_a[0][0]
# __________________________________________________________________________________________________
# res_3_conv_b (Conv2D)           (None, 8, 8, 1024)   2360320     activation_370[0][0]
# __________________________________________________________________________________________________
# bn_3_conv_b (BatchNormalization (None, 8, 8, 1024)   4096        res_3_conv_b[0][0]
# __________________________________________________________________________________________________
# activation_371 (Activation)     (None, 8, 8, 1024)   0           bn_3_conv_b[0][0]
# __________________________________________________________________________________________________
# res_3_conv_copy (Conv2D)        (None, 17, 17, 256)  33024       activation_369[0][0]
# __________________________________________________________________________________________________
# res_3_conv_c (Conv2D)           (None, 8, 8, 256)    262400      activation_371[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_91 (MaxPooling2D) (None, 8, 8, 256)    0           res_3_conv_copy[0][0]
# __________________________________________________________________________________________________
# bn_3_conv_c (BatchNormalization (None, 8, 8, 256)    1024        res_3_conv_c[0][0]
# __________________________________________________________________________________________________
# bn_3_conv_copy (BatchNormalizat (None, 8, 8, 256)    1024        max_pooling2d_91[0][0]
# __________________________________________________________________________________________________
# add_120 (Add)                   (None, 8, 8, 256)    0           bn_3_conv_c[0][0]
#                                                                  bn_3_conv_copy[0][0]
# __________________________________________________________________________________________________
# activation_372 (Activation)     (None, 8, 8, 256)    0           add_120[0][0]
# __________________________________________________________________________________________________
# res_3_identity_1_a (Conv2D)     (None, 8, 8, 256)    65792       activation_372[0][0]
# __________________________________________________________________________________________________
# bn_3_identity_1_a (BatchNormali (None, 8, 8, 256)    1024        res_3_identity_1_a[0][0]
# __________________________________________________________________________________________________
# activation_373 (Activation)     (None, 8, 8, 256)    0           bn_3_identity_1_a[0][0]
# __________________________________________________________________________________________________
# res_3_identity_1_b (Conv2D)     (None, 8, 8, 1024)   2360320     activation_373[0][0]
# __________________________________________________________________________________________________
# bn_3_identity_1_b (BatchNormali (None, 8, 8, 1024)   4096        res_3_identity_1_b[0][0]
# __________________________________________________________________________________________________
# activation_374 (Activation)     (None, 8, 8, 1024)   0           bn_3_identity_1_b[0][0]
# __________________________________________________________________________________________________
# res_3_identity_1_c (Conv2D)     (None, 8, 8, 256)    262400      activation_374[0][0]
# __________________________________________________________________________________________________
# bn_3_identity_1_c (BatchNormali (None, 8, 8, 256)    1024        res_3_identity_1_c[0][0]
# __________________________________________________________________________________________________
# add_121 (Add)                   (None, 8, 8, 256)    0           bn_3_identity_1_c[0][0]
#                                                                  activation_372[0][0]
# __________________________________________________________________________________________________
# activation_375 (Activation)     (None, 8, 8, 256)    0           add_121[0][0]
# __________________________________________________________________________________________________
# res_3_identity_2_a (Conv2D)     (None, 8, 8, 256)    65792       activation_375[0][0]
# __________________________________________________________________________________________________
# bn_3_identity_2_a (BatchNormali (None, 8, 8, 256)    1024        res_3_identity_2_a[0][0]
# __________________________________________________________________________________________________
# activation_376 (Activation)     (None, 8, 8, 256)    0           bn_3_identity_2_a[0][0]
# __________________________________________________________________________________________________
# res_3_identity_2_b (Conv2D)     (None, 8, 8, 1024)   2360320     activation_376[0][0]
# __________________________________________________________________________________________________
# bn_3_identity_2_b (BatchNormali (None, 8, 8, 1024)   4096        res_3_identity_2_b[0][0]
# __________________________________________________________________________________________________
# activation_377 (Activation)     (None, 8, 8, 1024)   0           bn_3_identity_2_b[0][0]
# __________________________________________________________________________________________________
# res_3_identity_2_c (Conv2D)     (None, 8, 8, 256)    262400      activation_377[0][0]
# __________________________________________________________________________________________________
# bn_3_identity_2_c (BatchNormali (None, 8, 8, 256)    1024        res_3_identity_2_c[0][0]
# __________________________________________________________________________________________________
# add_122 (Add)                   (None, 8, 8, 256)    0           bn_3_identity_2_c[0][0]
#                                                                  activation_375[0][0]
# __________________________________________________________________________________________________
# activation_378 (Activation)     (None, 8, 8, 256)    0           add_122[0][0]
# __________________________________________________________________________________________________
# res_4_conv_a (Conv2D)           (None, 8, 8, 512)    131584      activation_378[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_92 (MaxPooling2D) (None, 4, 4, 512)    0           res_4_conv_a[0][0]
# __________________________________________________________________________________________________
# bn_4_conv_a (BatchNormalization (None, 4, 4, 512)    2048        max_pooling2d_92[0][0]
# __________________________________________________________________________________________________
# activation_379 (Activation)     (None, 4, 4, 512)    0           bn_4_conv_a[0][0]
# __________________________________________________________________________________________________
# res_4_conv_b (Conv2D)           (None, 4, 4, 1024)   4719616     activation_379[0][0]
# __________________________________________________________________________________________________
# bn_4_conv_b (BatchNormalization (None, 4, 4, 1024)   4096        res_4_conv_b[0][0]
# __________________________________________________________________________________________________
# activation_380 (Activation)     (None, 4, 4, 1024)   0           bn_4_conv_b[0][0]
# __________________________________________________________________________________________________
# res_4_conv_copy (Conv2D)        (None, 8, 8, 256)    65792       activation_378[0][0]
# __________________________________________________________________________________________________
# res_4_conv_c (Conv2D)           (None, 4, 4, 256)    262400      activation_380[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_93 (MaxPooling2D) (None, 4, 4, 256)    0           res_4_conv_copy[0][0]
# __________________________________________________________________________________________________
# bn_4_conv_c (BatchNormalization (None, 4, 4, 256)    1024        res_4_conv_c[0][0]
# __________________________________________________________________________________________________
# bn_4_conv_copy (BatchNormalizat (None, 4, 4, 256)    1024        max_pooling2d_93[0][0]
# __________________________________________________________________________________________________
# add_123 (Add)                   (None, 4, 4, 256)    0           bn_4_conv_c[0][0]
#                                                                  bn_4_conv_copy[0][0]
# __________________________________________________________________________________________________
# activation_381 (Activation)     (None, 4, 4, 256)    0           add_123[0][0]
# __________________________________________________________________________________________________
# res_4_identity_1_a (Conv2D)     (None, 4, 4, 512)    131584      activation_381[0][0]
# __________________________________________________________________________________________________
# bn_4_identity_1_a (BatchNormali (None, 4, 4, 512)    2048        res_4_identity_1_a[0][0]
# __________________________________________________________________________________________________
# activation_382 (Activation)     (None, 4, 4, 512)    0           bn_4_identity_1_a[0][0]
# __________________________________________________________________________________________________
# res_4_identity_1_b (Conv2D)     (None, 4, 4, 1024)   4719616     activation_382[0][0]
# __________________________________________________________________________________________________
# bn_4_identity_1_b (BatchNormali (None, 4, 4, 1024)   4096        res_4_identity_1_b[0][0]
# __________________________________________________________________________________________________
# activation_383 (Activation)     (None, 4, 4, 1024)   0           bn_4_identity_1_b[0][0]
# __________________________________________________________________________________________________
# res_4_identity_1_c (Conv2D)     (None, 4, 4, 256)    262400      activation_383[0][0]
# __________________________________________________________________________________________________
# bn_4_identity_1_c (BatchNormali (None, 4, 4, 256)    1024        res_4_identity_1_c[0][0]
# __________________________________________________________________________________________________
# add_124 (Add)                   (None, 4, 4, 256)    0           bn_4_identity_1_c[0][0]
#                                                                  activation_381[0][0]
# __________________________________________________________________________________________________
# activation_384 (Activation)     (None, 4, 4, 256)    0           add_124[0][0]
# __________________________________________________________________________________________________
# res_4_identity_2_a (Conv2D)     (None, 4, 4, 512)    131584      activation_384[0][0]
# __________________________________________________________________________________________________
# bn_4_identity_2_a (BatchNormali (None, 4, 4, 512)    2048        res_4_identity_2_a[0][0]
# __________________________________________________________________________________________________
# activation_385 (Activation)     (None, 4, 4, 512)    0           bn_4_identity_2_a[0][0]
# __________________________________________________________________________________________________
# res_4_identity_2_b (Conv2D)     (None, 4, 4, 1024)   4719616     activation_385[0][0]
# __________________________________________________________________________________________________
# bn_4_identity_2_b (BatchNormali (None, 4, 4, 1024)   4096        res_4_identity_2_b[0][0]
# __________________________________________________________________________________________________
# activation_386 (Activation)     (None, 4, 4, 1024)   0           bn_4_identity_2_b[0][0]
# __________________________________________________________________________________________________
# res_4_identity_2_c (Conv2D)     (None, 4, 4, 256)    262400      activation_386[0][0]
# __________________________________________________________________________________________________
# bn_4_identity_2_c (BatchNormali (None, 4, 4, 256)    1024        res_4_identity_2_c[0][0]
# __________________________________________________________________________________________________
# add_125 (Add)                   (None, 4, 4, 256)    0           bn_4_identity_2_c[0][0]
#                                                                  activation_384[0][0]
# __________________________________________________________________________________________________
# activation_387 (Activation)     (None, 4, 4, 256)    0           add_125[0][0]
# __________________________________________________________________________________________________
# res_5_conv_a (Conv2D)           (None, 4, 4, 256)    65792       activation_387[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_94 (MaxPooling2D) (None, 2, 2, 256)    0           res_5_conv_a[0][0]
# __________________________________________________________________________________________________
# bn_5_conv_a (BatchNormalization (None, 2, 2, 256)    1024        max_pooling2d_94[0][0]
# __________________________________________________________________________________________________
# activation_388 (Activation)     (None, 2, 2, 256)    0           bn_5_conv_a[0][0]
# __________________________________________________________________________________________________
# res_5_conv_b (Conv2D)           (None, 2, 2, 1024)   2360320     activation_388[0][0]
# __________________________________________________________________________________________________
# bn_5_conv_b (BatchNormalization (None, 2, 2, 1024)   4096        res_5_conv_b[0][0]
# __________________________________________________________________________________________________
# activation_389 (Activation)     (None, 2, 2, 1024)   0           bn_5_conv_b[0][0]
# __________________________________________________________________________________________________
# res_5_conv_copy (Conv2D)        (None, 4, 4, 256)    65792       activation_387[0][0]
# __________________________________________________________________________________________________
# res_5_conv_c (Conv2D)           (None, 2, 2, 256)    262400      activation_389[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_95 (MaxPooling2D) (None, 2, 2, 256)    0           res_5_conv_copy[0][0]
# __________________________________________________________________________________________________
# bn_5_conv_c (BatchNormalization (None, 2, 2, 256)    1024        res_5_conv_c[0][0]
# __________________________________________________________________________________________________
# bn_5_conv_copy (BatchNormalizat (None, 2, 2, 256)    1024        max_pooling2d_95[0][0]
# __________________________________________________________________________________________________
# add_126 (Add)                   (None, 2, 2, 256)    0           bn_5_conv_c[0][0]
#                                                                  bn_5_conv_copy[0][0]
# __________________________________________________________________________________________________
# activation_390 (Activation)     (None, 2, 2, 256)    0           add_126[0][0]
# __________________________________________________________________________________________________
# res_5_identity_1_a (Conv2D)     (None, 2, 2, 256)    65792       activation_390[0][0]
# __________________________________________________________________________________________________
# bn_5_identity_1_a (BatchNormali (None, 2, 2, 256)    1024        res_5_identity_1_a[0][0]
# __________________________________________________________________________________________________
# activation_391 (Activation)     (None, 2, 2, 256)    0           bn_5_identity_1_a[0][0]
# __________________________________________________________________________________________________
# res_5_identity_1_b (Conv2D)     (None, 2, 2, 1024)   2360320     activation_391[0][0]
# __________________________________________________________________________________________________
# bn_5_identity_1_b (BatchNormali (None, 2, 2, 1024)   4096        res_5_identity_1_b[0][0]
# __________________________________________________________________________________________________
# activation_392 (Activation)     (None, 2, 2, 1024)   0           bn_5_identity_1_b[0][0]
# __________________________________________________________________________________________________
# res_5_identity_1_c (Conv2D)     (None, 2, 2, 256)    262400      activation_392[0][0]
# __________________________________________________________________________________________________
# bn_5_identity_1_c (BatchNormali (None, 2, 2, 256)    1024        res_5_identity_1_c[0][0]
# __________________________________________________________________________________________________
# add_127 (Add)                   (None, 2, 2, 256)    0           bn_5_identity_1_c[0][0]
#                                                                  activation_390[0][0]
# __________________________________________________________________________________________________
# activation_393 (Activation)     (None, 2, 2, 256)    0           add_127[0][0]
# __________________________________________________________________________________________________
# res_5_identity_2_a (Conv2D)     (None, 2, 2, 256)    65792       activation_393[0][0]
# __________________________________________________________________________________________________
# bn_5_identity_2_a (BatchNormali (None, 2, 2, 256)    1024        res_5_identity_2_a[0][0]
# __________________________________________________________________________________________________
# activation_394 (Activation)     (None, 2, 2, 256)    0           bn_5_identity_2_a[0][0]
# __________________________________________________________________________________________________
# res_5_identity_2_b (Conv2D)     (None, 2, 2, 1024)   2360320     activation_394[0][0]
# __________________________________________________________________________________________________
# bn_5_identity_2_b (BatchNormali (None, 2, 2, 1024)   4096        res_5_identity_2_b[0][0]
# __________________________________________________________________________________________________
# activation_395 (Activation)     (None, 2, 2, 1024)   0           bn_5_identity_2_b[0][0]
# __________________________________________________________________________________________________
# res_5_identity_2_c (Conv2D)     (None, 2, 2, 256)    262400      activation_395[0][0]
# __________________________________________________________________________________________________
# bn_5_identity_2_c (BatchNormali (None, 2, 2, 256)    1024        res_5_identity_2_c[0][0]
# __________________________________________________________________________________________________
# add_128 (Add)                   (None, 2, 2, 256)    0           bn_5_identity_2_c[0][0]
#                                                                  activation_393[0][0]
# __________________________________________________________________________________________________
# activation_396 (Activation)     (None, 2, 2, 256)    0           add_128[0][0]
# __________________________________________________________________________________________________
# Averagea_Pooling (AveragePoolin (None, 1, 1, 256)    0           activation_396[0][0]
# __________________________________________________________________________________________________
# flatten_6 (Flatten)             (None, 256)          0           Averagea_Pooling[0][0]
# __________________________________________________________________________________________________
# dense_30 (Dense)                (None, 4096)         1052672     flatten_6[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 4096)         0           dense_30[0][0]
# __________________________________________________________________________________________________
# dense_31 (Dense)                (None, 2048)         8390656     dropout_12[0][0]
# __________________________________________________________________________________________________
# dropout_13 (Dropout)            (None, 2048)         0           dense_31[0][0]
# __________________________________________________________________________________________________
# dense_32 (Dense)                (None, 1024)         2098176     dropout_13[0][0]
# __________________________________________________________________________________________________
# dense_33 (Dense)                (None, 512)          524800      dense_32[0][0]
# __________________________________________________________________________________________________
# dense_34 (Dense)                (None, 1)            513         dense_33[0][0]
# ==================================================================================================
# Total params: 45,761,281
# Trainable params: 45,725,569
# Non-trainable params: 35,712
# __________________________________________________________________________________________________

# %%
#adam = tf.keras.optimizers.Adam(lr = 0.01) #, beta_1=0.9, beta_2=0.999, amsgrad=False
optimizer = tf.keras.optimizers.Adam(lr = 0.0001, beta_1=0.9, beta_2=0.999, amsgrad=False) #, beta_1=0.9, beta_2=0.999, amsgrad=False
#model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])

# %%
# save the best model with least validation loss
checkpointer_dir = "drive/My Drive/Conference_ICOSES/"
checkpointer_name  = "weights_32p_2.hdf5"
checkpointer = ModelCheckpoint(filepath = checkpointer_dir+checkpointer_name, verbose = 1, save_best_only = True)

# %%
#39312
history = model.fit(np_train_dataset2, np_train_label_seed2, 
                    shuffle=True, 
                    batch_size = 32, 
                    epochs= 15, 
                    #steps_per_epoch = 2,
                    validation_split = 0.1, 
                    callbacks=[checkpointer]
                    )
# Out:
# Epoch 1/15
# 1106/1106 [==============================] - ETA: 0s - loss: 0.5517 - accuracy: 0.7025
# Epoch 00001: val_loss improved from inf to 0.47236, saving model to drive/My Drive/Conference_ICOSES/weights_32p_2.hdf5
# 1106/1106 [==============================] - 252s 228ms/step - loss: 0.5517 - accuracy: 0.7025 - val_loss: 0.4724 - val_accuracy: 0.7622
# Epoch 2/15
# 1106/1106 [==============================] - ETA: 0s - loss: 0.4445 - accuracy: 0.7802
# Epoch 00002: val_loss did not improve from 0.47236
# 1106/1106 [==============================] - 244s 220ms/step - loss: 0.4445 - accuracy: 0.7802 - val_loss: 0.7461 - val_accuracy: 0.6839
# Epoch 3/15
# 1106/1106 [==============================] - ETA: 0s - loss: 0.3880 - accuracy: 0.8166
# Epoch 00003: val_loss did not improve from 0.47236
# 1106/1106 [==============================] - 243s 220ms/step - loss: 0.3880 - accuracy: 0.8166 - val_loss: 0.7270 - val_accuracy: 0.6966
# Epoch 4/15
# 1106/1106 [==============================] - ETA: 0s - loss: 0.3464 - accuracy: 0.8376
# Epoch 00004: val_loss improved from 0.47236 to 0.45242, saving model to drive/My Drive/Conference_ICOSES/weights_32p_2.hdf5
# 1106/1106 [==============================] - 249s 225ms/step - loss: 0.3464 - accuracy: 0.8376 - val_loss: 0.4524 - val_accuracy: 0.7724
# Epoch 5/15
# 1106/1106 [==============================] - ETA: 0s - loss: 0.3087 - accuracy: 0.8597
# Epoch 00005: val_loss improved from 0.45242 to 0.39495, saving model to drive/My Drive/Conference_ICOSES/weights_32p_2.hdf5
# 1106/1106 [==============================] - 249s 225ms/step - loss: 0.3087 - accuracy: 0.8597 - val_loss: 0.3949 - val_accuracy: 0.8090
# Epoch 6/15
# 1106/1106 [==============================] - ETA: 0s - loss: 0.2735 - accuracy: 0.8776
# Epoch 00006: val_loss did not improve from 0.39495
# 1106/1106 [==============================] - 243s 220ms/step - loss: 0.2735 - accuracy: 0.8776 - val_loss: 0.8390 - val_accuracy: 0.6834
# Epoch 7/15
# 1106/1106 [==============================] - ETA: 0s - loss: 0.2405 - accuracy: 0.8948
# Epoch 00007: val_loss did not improve from 0.39495
# 1106/1106 [==============================] - 241s 218ms/step - loss: 0.2405 - accuracy: 0.8948 - val_loss: 0.9919 - val_accuracy: 0.6823
# Epoch 8/15
# 1106/1106 [==============================] - ETA: 0s - loss: 0.2111 - accuracy: 0.9084
# Epoch 00008: val_loss improved from 0.39495 to 0.32227, saving model to drive/My Drive/Conference_ICOSES/weights_32p_2.hdf5
# 1106/1106 [==============================] - 247s 223ms/step - loss: 0.2111 - accuracy: 0.9084 - val_loss: 0.3223 - val_accuracy: 0.8594
# Epoch 9/15
# 1106/1106 [==============================] - ETA: 0s - loss: 0.1783 - accuracy: 0.9252
# Epoch 00009: val_loss did not improve from 0.32227
# 1106/1106 [==============================] - 241s 218ms/step - loss: 0.1783 - accuracy: 0.9252 - val_loss: 0.4591 - val_accuracy: 0.8082
# Epoch 10/15
# 1106/1106 [==============================] - ETA: 0s - loss: 0.1500 - accuracy: 0.9393
# Epoch 00010: val_loss improved from 0.32227 to 0.28213, saving model to drive/My Drive/Conference_ICOSES/weights_32p_2.hdf5
# 1106/1106 [==============================] - 247s 224ms/step - loss: 0.1500 - accuracy: 0.9393 - val_loss: 0.2821 - val_accuracy: 0.8914
# Epoch 11/15
# 1106/1106 [==============================] - ETA: 0s - loss: 0.1242 - accuracy: 0.9502
# Epoch 00011: val_loss did not improve from 0.28213
# 1106/1106 [==============================] - 241s 218ms/step - loss: 0.1242 - accuracy: 0.9502 - val_loss: 0.5385 - val_accuracy: 0.8113
# Epoch 12/15
# 1106/1106 [==============================] - ETA: 0s - loss: 0.1046 - accuracy: 0.9585
# Epoch 00012: val_loss did not improve from 0.28213
# 1106/1106 [==============================] - 243s 220ms/step - loss: 0.1046 - accuracy: 0.9585 - val_loss: 0.4398 - val_accuracy: 0.8342
# Epoch 13/15
# 1106/1106 [==============================] - ETA: 0s - loss: 0.0919 - accuracy: 0.9638
# Epoch 00013: val_loss improved from 0.28213 to 0.27296, saving model to drive/My Drive/Conference_ICOSES/weights_32p_2.hdf5
# 1106/1106 [==============================] - 249s 225ms/step - loss: 0.0919 - accuracy: 0.9638 - val_loss: 0.2730 - val_accuracy: 0.9130
# Epoch 14/15
# 1106/1106 [==============================] - ETA: 0s - loss: 0.0746 - accuracy: 0.9716
# Epoch 00014: val_loss did not improve from 0.27296
# 1106/1106 [==============================] - 244s 220ms/step - loss: 0.0746 - accuracy: 0.9716 - val_loss: 0.5228 - val_accuracy: 0.8410
# Epoch 15/15
# 1106/1106 [==============================] - ETA: 0s - loss: 0.0688 - accuracy: 0.9741
# Epoch 00015: val_loss did not improve from 0.27296
# 1106/1106 [==============================] - 243s 220ms/step - loss: 0.0688 - accuracy: 0.9741 - val_loss: 0.5955 - val_accuracy: 0.8283

# %%
#model = load_model(checkpointer_dir+checkpointer_name)

# %%
result = model.evaluate(np_test_dataset2, np_test_label_seed2)
print("Accuracy : {}, Loss: {}".format(result[1], result[0]))
# Out:
# 136/136 [==============================] - 9s 63ms/step - loss: 0.9644 - accuracy: 0.7716
# Accuracy : 0.7716390490531921, Loss: 0.96443772315979

# %%
#predict = model.predict(np_test_dataset2)

# %%
# Getting the model history keys 
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
# plot the training artifacts

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train_loss','val_loss'], loc = 'upper right')
plt.show()

# %%
# plot the training artifacts

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train_acc','val_acc'], loc = 'upper right')
plt.show()

# %%
for true,pred in zip(np_test_label_seed2,predict):
    print(true,'-',pred)
